td>4</td><td>1</td><td>26.33</td><td>2025-02-20</td><td>219.72</td></tr><tr><td>26</td><td>44</td><td>33</td><td>13</td><td>3</td><td>1.25</td><td>2024-08-09</td><td>110.21</td></tr><tr><td>27</td><td>84</td><td>94</td><td>15</td><td>1</td><td>11.93</td><td>2024-12-18</td><td>249.09</td></tr><tr><td>28</td><td>30</td><td>27</td><td>11</td><td>1</td><td>22.87</td><td>2024-11-04</td><td>80.09</td></tr><tr><td>29</td><td>190</td><td>36</td><td>10</td><td>1</td><td>13.65</td><td>2025-01-30</td><td>349.86</td></tr><tr><td>30</td><td>75</td><td>29</td><td>3</td><td>2</td><td>8.02</td><td>2025-01-02</td><td>548.66</td></tr><tr><td>31</td><td>128</td><td>38</td><td>14</td><td>4</td><td>6.59</td><td>2024-08-07</td><td>199.34</td></tr><tr><td>32</td><td>92</td><td>57</td><td>16</td><td>2</td><td>3.95</td><td>2025-06-13</td><td>93.74</td></tr><tr><td>33</td><td>190</td><td>97</td><td>10</td><td>4</td><td>25.71</td><td>2025-05-22</td><td>7 ...

# %% [markdown]
# # **DBUTILS**

# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
#   <h3></h3><b>credentials: DatabricksCredentialUtils</b> -> Utilities for interacting with credentials within notebooks<br /><b>data: DataUtils</b> -> Utilities for understanding and interacting with datasets (EXPERIMENTAL)<br /><b>fs: DbfsUtils</b> -> Manipulates the Databricks filesystem (DBFS) from the console<br /><b>jobs: JobsUtils</b> -> Utilities for leveraging jobs features<br /><b>library: LibraryUtils</b> -> Utilities for session isolated libraries<br /><b>meta: MetaUtils</b> -> Methods to hook into the compiler (EXPERIMENTAL)<br /><b>notebook: NotebookUtils</b> -> Utilities for the control flow of a notebook (EXPERIMENTAL)<br /><b>preview: Preview</b> -> Utilities under preview category<br /><b>secrets: SecretUtils</b> -> Provides utilities for leveraging secrets within notebooks<br /><b>widgets: WidgetsUtils</b> -> Methods to create and get bound value of input widgets inside notebooks<br /><br /></div>

# %%
dbutils.fs.ls("/Volumes/databricksansh/bronze/bronze_volume/sales/")
# Out:
# [FileInfo(path='dbfs:/Volumes/databricksansh/bronze/bronze_volume/sales/fact_sales.csv', name='fact_sales.csv', size=38425, modificationTime=1751237311000)]

# %%
dbutils.fs.mkdirs("/Volumes/databricksansh/bronze/bronze_volume/customers")
# Out:
# True

# %%
dbutils.fs.cp("/Volumes/databricksansh/bronze/bronze_volume/sales/","/Volumes/databricksansh/bronze/bronze_volume/customers/",True)
# Out:
# True

# %%
dbutils.fs.rm("/Volumes/databricksansh/bronze/bronze_volume/customers/fact_sales.csv")
# Out:
# True

# %%
dbutils.fs.put("/Volumes/databricksansh/bronze/bronze_volume/customers/test.py","print(Hello Ansh Lamba)",True)
# Out:
# Wrote 23 bytes.
# True

# %%
all_items = dbutils.fs.ls("/Volumes/databricksansh/bronze/bronze_volume/customers/")
all_items
# Out:
# [FileInfo(path='dbfs:/Volumes/databricksansh/bronze/bronze_volume/customers/test.py', name='test.py', size=23, modificationTime=1751291524000),
#  FileInfo(path='dbfs:/Volumes/databricksansh/bronze/bronze_volume/customers/test.txt', name='test.txt', size=16, modificationTime=1751291492000)]

# %%
file_names = [i.name for i in all_items]
file_names
# Out:
# ['test.py', 'test.txt']

# %%
for i in file_names:
    dbutils.fs.rm(f"/Volumes/databricksansh/bronze/bronze_volume/customers/{i}")

# %%
dbutils.widgets.text("par1","")

# %%
par1_value = dbutils.widgets.get("par1")
par1_value
# Out:
# 'ansh ansh'
