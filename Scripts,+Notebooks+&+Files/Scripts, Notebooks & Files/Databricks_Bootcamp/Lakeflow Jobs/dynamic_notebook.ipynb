# %%
dbutils.widgets.text("para1","")

# %%
para1_value = dbutils.widgets.get("para1")
para1_value
# Out:
# ''

# %% [markdown]
# ### **GET VALUE**

# %%
var2 = dbutils.jobs.taskValues.get('lookup', 'lookup_output')
var2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <command-8636826275248864>, line 1
# ----> 1 dbutils.job.taskValues.get('lookup', 'lookup_output')
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:733, in DBUtils.__getattr__(self, item)
#     730     self.data = DataHandler(self.entry_point, self.displayHTML, self.spark)
#     731     return self.data
# --> 733 raise AttributeError
#
# AttributeError:
