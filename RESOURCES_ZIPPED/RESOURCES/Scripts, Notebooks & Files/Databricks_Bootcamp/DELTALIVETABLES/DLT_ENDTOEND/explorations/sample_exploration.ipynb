# %%
# %sql
SELECT * FROM databricksansh.gold.products_silver
WHERE product_id = 29
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>category</th><th>price</th><th>_rescued_data</th><th>processDate</th></tr></thead><tbody><tr><td>29</td><td>Provide Thank</td><td>Electronics</td><td>314.98</td><td>null</td><td>2025-07-03T03:45:27.188Z</td></tr></tbody></table></div>
